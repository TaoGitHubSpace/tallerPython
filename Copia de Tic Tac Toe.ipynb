# %%
f=["a","b","c","d","e","f","g","h","i"]
print("[",f[0],f[1],f[2],"]"),
print("[",f[3],f[4],f[5],"]"),
print("[",f[6],f[7],f[8],"]")

while True:
    V1=f[0]==f[1]==f[2]
    V2=f[3]==f[4]==f[5]
    V3=f[6]==f[7]==f[8]
    V4=f[0]==f[3]==f[6]
    V5=f[1]==f[4]==f[7]
    V6=f[2]==f[5]==f[8]
    V7=f[0]==f[4]==f[8]
    V8=f[2]==f[4]==f[6]
    if (V1 or V2 or V3 or V4 or V5 or V6 or V7 or V8)== True:
        print("Ganaste")
        break
    while True:
        U1=input("Usuario 1, por favor elija una ubicación\n").lower()
        if U1 in f:
            f[f.index(U1)]="X"
            break
        else:
            print("Ubicación inexistente")
    print("[",f[0],f[1],f[2],"]"),
    print("[",f[3],f[4],f[5],"]"),
    print("[",f[6],f[7],f[8],"]")
    V1=f[0]==f[1]==f[2]
    V2=f[3]==f[4]==f[5]
    V3=f[6]==f[7]==f[8]
    V4=f[0]==f[3]==f[6]
    V5=f[1]==f[4]==f[7]
    V6=f[2]==f[5]==f[8]
    V7=f[0]==f[4]==f[8]
    V8=f[2]==f[4]==f[6]
    if (V1 or V2 or V3 or V4 or V5 or V6 or V7 or V8)== True:
        print("Ganaste Usuario 1")
        break
    
    while True:
        U2=input("Usuario 2, por favor elija una ubicación\n").lower()
        if U2 in f:
            f[f.index(U2)]="O"
            break
        else:
            print("Ubicación inexistente")
    print("[",f[0],f[1],f[2],"]"),
    print("[",f[3],f[4],f[5],"]"),
    print("[",f[6],f[7],f[8],"]")
    V1=f[0]==f[1]==f[2]
    V2=f[3]==f[4]==f[5]
    V3=f[6]==f[7]==f[8]
    V4=f[0]==f[3]==f[6]
    V5=f[1]==f[4]==f[7]
    V6=f[2]==f[5]==f[8]
    V7=f[0]==f[4]==f[8]
    V8=f[2]==f[4]==f[6]
    if (V1 or V2 or V3 or V4 or V5 or V6 or V7 or V8)== True:
        print("Ganaste Usuario 2")
        break
# Out:
# [ a b c ]
# [ d e f ]
# [ g h i ]
# Usuario 1, por favor elija una ubicación
# a
# [ X b c ]
# [ d e f ]
# [ g h i ]
# Usuario 2, por favor elija una ubicación
# e
# [ X b c ]
# [ d O f ]
# [ g h i ]
# Usuario 1, por favor elija una ubicación
# d
# [ X b c ]
# [ X O f ]
# [ g h i ]
# Usuario 2, por favor elija una ubicación
# h
# [ X b c ]
# [ X O f ]
# [ g O i ]
# Usuario 1, por favor elija una ubicación
# g
# [ X b c ]
# [ X O f ]
# [ X O i ]
# Ganaste Usuario 1
