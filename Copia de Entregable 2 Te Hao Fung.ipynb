# %%
Sel=input("Elige un Departamento\n A. Antioquia \n B. Cundinamarca \n C. Quindio \n D. Valle \n ").upper()
if Sel=="A": #Seleccion Antioquia
    Ciu=input("Selecciona una Ciudad\n A. Medellin \n B. Rionegro \n C. Caldas \n D. Guatape \n ").upper()
    if Ciu == "A": #Selecciona Medellin
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Medellin
            Des=input("Selecciona un restaurante\n A. Mercado del Rio \n B. CiboSano \n C. Gokela \n D. Donde Paco \n ").upper()
            if Des=="A":
                print("Descripción de Mercado del Rio en Medellin")
            elif Des=="B":
                print("Descripción de CiboSano en Medellin")
            elif Des=="C":
                print("Descripción de Gokela en Medellin")
            elif Des=="D":
                print("Descripción de Donde Paco en Medellin")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Medellin
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Medellin")
            elif Des=="B":
                print("Descripción de Mamiferos de Medellin")
            elif Des=="C":
                print("Descripción de Anfibios de Medellin")
            elif Des=="D":
                print("Descripción de Reptiles de Medellin")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Medellin
            Des=input("Selecciona un dato histórico\n A. 1816 \n B. 1948 \n C. 1995 \n D. 2010 \n ").upper()
            if Des=="A": 
                print("Medellin se fundó en 1816")
            elif Des=="B":
                print("Medellin fue la capital provisional de Colombia durante el Bogotazo, en Abril de 1948")
            elif Des=="C":
                print("El metro fue inaugurado el 30 de Nov de 1995")
            elif Des=="D":
                print("Los IX Juegos Suramericanos se celebraron en medellin en Marzo del 2010")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Medellin
            Des=input("Selecciona un cantante\n A. Lucas Arnau \n B. Naty Botero \n C. Sebastian Yatra \n D. Miranda \n ").upper()
            if Des=="A": 
                print("Biografía de Lucas Arnau de Medellin")
            elif Des=="B":
                print("Biografía de Naty Botero de Medellin")
            elif Des=="C":
                print("Biografía de Sebastian Yatra de Medellin")
            elif Des=="D":
                print("Biografía de Miranda de Medellin")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Medellin
    elif Ciu =="B": # Selecciona Rionegro
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Rionegro
            Des=input("Selecciona un restaurante\n A. Brasas parrilla bar \n B. Entre mares \n C. La Cantaleta \n D. El rancherito \n ").upper()
            if Des=="A":
                print("Descripción de Brasas parrilla bar en Rionegro")
            elif Des=="B":
                print("Descripción de Entre mares en Rionegro")
            elif Des=="C":
                print("Descripción de La Cantaleta en Rionegro")
            elif Des=="D":
                print("Descripción de El rancherito en Rionegro")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Rionegro
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Rionegro")
            elif Des=="B":
                print("Descripción de Mamiferos de Rionegro")
            elif Des=="C":
                print("Descripción de Anfibios de Rionegro")
            elif Des=="D":
                print("Descripción de Reptiles de Rionegro")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Rionegro
            Des=input("Selecciona un dato histórico\n A. 6 Dic 1542 \n B. 21 Mar 1812 \n C. 7 Feb 1813 \n D. 28 Ago 1819 \n ").upper()
            if Des=="A": 
                print("Rionegro se fundó el 6 de Diciembre de 1542")
            elif Des=="B":
                print("El 21 de marzo de 1812, en la sacristía de la catedral de Rionegro (hoy museo), fue firmada y proclamada la Constitución del Estado Libre de Antioquia")
            elif Des=="C":
                print("El 7 de febrero de 1813 las autoridades de Rionegro declaran la independencia de la población frente a la Corona española y la figura de Fernando VII, aún preso por los franceses")
            elif Des=="D":
                print("El 28 de agosto 1819 José María Córdova llegó a Rionegro y nombró a José Manuel Restrepo como jefe civil mientras el ejercía la comandancia militar")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Rionegro
            Des=input("Selecciona un cantante\n A. Gustavo Quintero \n B. CanRionegro2 \n C. CanRionegro3 \n D. CanRionegro4 \n ").upper()
            if Des=="A": 
                print("Biografía de Gustavo El Loko Quintero de Rionegro")
            elif Des=="B":
                print("Biografía de Cantante de Rionegro2")
            elif Des=="C":
                print("Biografía de Cantante de Rionegro3")
            elif Des=="D":
                print("Biografía de Cantante de Rionegro4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Rionegro    
    elif Ciu =="C":# Selecciona Caldas
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Caldas
            Des=input("Selecciona un restaurante\n A. Ambrosia \n B. El llanerito \n C. Azahares \n D. Emilia Steakhouse \n ").upper()
            if Des=="A":
                print("Descripción de Ambrosia en Caldas")
            elif Des=="B":
                print("Descripción de El llanerito en Caldas")
            elif Des=="C":
                print("Descripción de Azahares en Caldas")
            elif Des=="D":
                print("Descripción de Emilia Steakhouse en Caldas")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Caldas
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Caldas")
            elif Des=="B":
                print("Descripción de Mamiferos de Caldas")
            elif Des=="C":
                print("Descripción de Anfibios de Caldas")
            elif Des=="D":
                print("Descripción de Reptiles de Caldas")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Caldas
            Des=input("Selecciona un dato histórico\n A. 1840 \n B. 1844 \n C. 1848 \n D. 1853 \n ").upper()
            if Des=="A": 
                print("Hacia 1840 Don Roque Mejía, dueño de las tierras, resolvió ceder a título gratuito los terrenos para plaza y calles en un paraje comprendido entre el río Medellín y la quebrada La Valeria")
            elif Des=="B":
                print("En 1844 ese pequeño poblado dependía de La Estrella y fue elevado a la categoría de fracción")
            elif Des=="C":
                print("El 15 de septiembre de 1848 los moradores del lugar elevaron una solicitud a la Cámara Provincial de Antioquia, reunida entonces, pidiendo el levantamiento del distrito")
            elif Des=="D":
                print("El 5 de marzo de 1853 el gobernador de la Provincia de Medellín, señor José María Facio Lince dictó el decreto para la creación del distrito, todos los esfuerzos se encaminaron a conseguir la erección de la parroquia")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Caldas
            Des=input("Selecciona un cantante\n A. Yeison Jiménez \n B. Sebastián Yepes \n C. CanCaldas3 \n D. CanCaldas4 \n ").upper()
            if Des=="A": 
                print("Biografía de Yeison Jiménez de Caldas")
            elif Des=="B":
                print("Biografía de Sebastián Yepes de Caldas")
            elif Des=="C":
                print("Biografía de CanCaldas3")
            elif Des=="D":
                print("Biografía de CanCaldas4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Caldas
    elif Ciu =="D": # Selecciona Guatape
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Guatape
            Des=input("Selecciona un restaurante\n A. Getaway Pub & Grill \n B. Café sin P \n C. ZOCAROLLS \n D. Guatacrêp' \n ").upper()
            if Des=="A":
                print("Descripción de Getaway Pub & Grill en Guatape")
            elif Des=="B":
                print("Descripción de Café sin P en Guatape")
            elif Des=="C":
                print("Descripción de ZOCAROLLS en Guatape")
            elif Des=="D":
                print("Descripción de Guatacrêp' en Guatape")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Guatape
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Guatape")
            elif Des=="B":
                print("Descripción de Mamiferos de Guatape")
            elif Des=="C":
                print("Descripción de Anfibios de Guatape")
            elif Des=="D":
                print("Descripción de Reptiles de Guatape")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Guatape
            Des=input("Selecciona un dato histórico\n A. 1811 \n B. 1867 \n C. 1970 \n D. 2018 \n ").upper()
            if Des=="A": 
                print("Fundación: 4 de octubre de 1811")
            elif Des=="B":
                print("Erección en municipio: ley 104 de septiembre de 1867")
            elif Des=="C":
                print("Las Empresas Públicas de Medellín construyeron aquí en los años 1970 un gran complejo hidroeléctrico con la inundación de 2262 hectáreas de tierra. Este megaproyecto produjo grandes impactos en lo social, económico, político, ambiental y cultural en la localidad.")
            elif Des=="D":
                print("En 2018 Guatapé lanza al mundo su marca turística con la cual se quiere dar a conocer al mundo 'Guatapé un destino a todo color' dando así representación a este mágico lugar lleno de zócalos, historia y mucho color.")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Guatape
            Des=input("Selecciona un cantante\n A. CanGuatape1 \n B. CanGuatape2 \n C. CanGuatape3 \n D. CanGuatape4 \n ").upper()
            if Des=="A": 
                print("Biografía de CanGuatape1")
            elif Des=="B":
                print("Biografía de CanGuatape2")
            elif Des=="C":
                print("Biografía de CanGuatape3")
            elif Des=="D":
                print("Biografía de CanGuatape4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Guatape          
    else:
        print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de Ciudad
elif Sel =="B": # Cundinamarca
    Ciu=input("Selecciona una Ciudad\n A. Bogota \n B. Chia \n C. Zipaquira \n D. Cota \n ").upper()
    if Ciu == "A": #Selecciona Bogota
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Bogota
            Des=input("Selecciona un restaurante\n A. Capitalino Restaurant \n B. McCarthy's Irish Pub \n C. Café Restaurante El Gato Gris \n D. La Provence de Andrei \n ").upper()
            if Des=="A":
                print("Descripción de Capitalino Restaurant en Bogota")
            elif Des=="B":
                print("Descripción de McCarthy's Irish Pub en Bogota")
            elif Des=="C":
                print("Descripción de Café Restaurante El Gato Gris en Bogotá")
            elif Des=="D":
                print("Descripción de La Provence de Andrei en Bogotá")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Bogota
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Bogota")
            elif Des=="B":
                print("Descripción de Mamiferos de Bogota")
            elif Des=="C":
                print("Descripción de Anfibios de Bogota")
            elif Des=="D":
                print("Descripción de Reptiles de Bogota")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Bogota
            Des=input("Selecciona un dato histórico\n A. 1538 \n B. 1539 \n C. 1540 \n D. 1830 \n ").upper()
            if Des=="A": 
                print("Bogotá fue fundada como capital del Nuevo Reino de Granada el 6 de agosto de 1538 por el conquistador español Gonzalo Jiménez de Quesada después de una dura expedición a los Andes.")
            elif Des=="B":
                print("El 22 de abril de 1539, Jiménez de Quesada también realizó la 'fundación jurídica' de Santafé en compañía de Nicolás Federmann y Sebastián de Belalcázar.37​ Inicialmente llamada Nuestra Señora de la Esperanza, en la fundación jurídica cambió su nombre a Santafé")
            elif Des=="C":
                print("La real cédula del emperador Carlos I elevó a Santafé a la categoría de ciudad, el 27 de julio de 1540")
            elif Des=="D":
                print("La ciudad se convirtió en capital de la Gran Colombia hasta 1830")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Bogota
            Des=input("Selecciona un cantante\n A. Andrés Cepeda \n B. CanBog1 \n C. CanBog1 \n D. CanBog1 \n ").upper()
            if Des=="A": 
                print("Biografía de Andrés Cepeda de Bogotá")
            elif Des=="B":
                print("Biografía de CanBog1")
            elif Des=="C":
                print("Biografía de CanBog1")
            elif Des=="D":
                print("Biografía de CanBog1")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Bogota
    elif Ciu =="B": # Selecciona Chia
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Chia
            Des=input("Selecciona un restaurante\n A. ComChia1 \n B. ComChia2 \n C. ComChia3 \n D. ComChia4 \n ").upper()
            if Des=="A":
                print("Descripción de ComChia1")
            elif Des=="B":
                print("Descripción de ComChia2")
            elif Des=="C":
                print("Descripción de ComChia3")
            elif Des=="D":
                print("Descripción de ComChia4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Chia
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Chia")
            elif Des=="B":
                print("Descripción de Mamiferos de Chia")
            elif Des=="C":
                print("Descripción de Anfibios de Chia")
            elif Des=="D":
                print("Descripción de Reptiles de Chia")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Chia
            Des=input("Selecciona un dato histórico\n A. DatChia1 \n B. DatChia2 \n C. DatChia3 \n D. DatChia4 \n ").upper()
            if Des=="A": 
                print("DatChia1")
            elif Des=="B":
                print("DatChia2")
            elif Des=="C":
                print("DatChia")
            elif Des=="D":
                print("DatChia4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Chia
            Des=input("Selecciona un cantante\n A. CanChia1 \n B. CanChia2 \n C. CanChia3 \n D. CanChia4 \n ").upper()
            if Des=="A": 
                print("Biografía de CanChia1")
            elif Des=="B":
                print("Biografía de CanChia2")
            elif Des=="C":
                print("Biografía de CanChia3")
            elif Des=="D":
                print("Biografía de CanChia4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Chia    
    elif Ciu =="C":# Selecciona Zipaquira
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Zipa
            Des=input("Selecciona un restaurante\n A. ComZipa1 \n B. ComZipa2 \n C. ComZipa3 \n D. ComZipa4 \n ").upper()
            if Des=="A":
                print("Descripción de ComZipa1")
            elif Des=="B":
                print("Descripción de ComZipa2")
            elif Des=="C":
                print("Descripción de ComZipa3")
            elif Des=="D":
                print("Descripción de ComZipa4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Zipa
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Zipa")
            elif Des=="B":
                print("Descripción de Mamiferos de Zipa")
            elif Des=="C":
                print("Descripción de Anfibios de Zipa")
            elif Des=="D":
                print("Descripción de Reptiles de Zipa")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Zipa
            Des=input("Selecciona un dato histórico\n A. DatZipa1 \n B. DatZipa2 \n C. DatZipa3 \n D. DatZipa4 \n ").upper()
            if Des=="A": 
                print("DatZipa1")
            elif Des=="B":
                print("DatZipa2")
            elif Des=="C":
                print("DatZipa3")
            elif Des=="D":
                print("DatZipa4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Zipa
            Des=input("Selecciona un cantante\n A. CanZipa1 \n B. CanZipa2 \n C. CanZipa3 \n D. CanZipa4 \n ").upper()
            if Des=="A": 
                print("Biografía de CanZipa1")
            elif Des=="B":
                print("Biografía de CanZipa2")
            elif Des=="C":
                print("Biografía de CanZipa3")
            elif Des=="D":
                print("Biografía de CanZipa4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Zipa
    elif Ciu =="D": # Selecciona Cota
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Cota
            Des=input("Selecciona un restaurante\n A. ComCCota1 \n B. ComCota2 \n C. ComCota3 \n D. ComCota4 \n ").upper()
            if Des=="A":
                print("Descripción de ComCota1")
            elif Des=="B":
                print("Descripción de ComCota2")
            elif Des=="C":
                print("Descripción de ComCota3")
            elif Des=="D":
                print("Descripción de ComCota4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Cota
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Cota")
            elif Des=="B":
                print("Descripción de Mamiferos de Cota")
            elif Des=="C":
                print("Descripción de Anfibios de Cota")
            elif Des=="D":
                print("Descripción de Reptiles de Cota")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Cota
            Des=input("Selecciona un dato histórico\n A. DatCota1 \n B. DatCota2 \n C. DatCota3 \n D. DatCota4 \n ").upper()
            if Des=="A": 
                print("DatCota1")
            elif Des=="B":
                print("DatCota2")
            elif Des=="C":
                print("DatCota3")
            elif Des=="D":
                print("DatCota4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Cota
            Des=input("Selecciona un cantante\n A. CanCota1 \n B. CanCota2 \n C. CanCota3 \n D. CanCota4 \n ").upper()
            if Des=="A": 
                print("Biografía de CanCota1")
            elif Des=="B":
                print("Biografía de CanCota2")
            elif Des=="C":
                print("Biografía de CanCota3")
            elif Des=="D":
                print("Biografía de CanCota4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Cota          
    else:
        print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de Ciudad
elif Sel =="C": # Quindio
    Ciu=input("Selecciona una Ciudad\n A. Armenia \n B. Pereira \n C. Manizales \n D. Cartagp \n ").upper()
    if Ciu == "A": #Selecciona Armenia
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Armenia
            Des=input("Selecciona un restaurante\n A. ComArme1 \n B. ComArme2 \n C. ComArme3 \n D. ComArme4 \n ").upper()
            if Des=="A":
                print("Descripción de ComArme1")
            elif Des=="B":
                print("Descripción de ComArme2")
            elif Des=="C":
                print("Descripción de ComArme3")
            elif Des=="D":
                print("Descripción de ComArme4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Armenia
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Armenia")
            elif Des=="B":
                print("Descripción de Mamiferos de Armenia")
            elif Des=="C":
                print("Descripción de Anfibios de Armenia")
            elif Des=="D":
                print("Descripción de Reptiles de Armenia")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Armenia
            Des=input("Selecciona un dato histórico\n A. DatArm1 \n B. DatArm2 \n C. DatArm3 \n D. DatArm4 \n ").upper()
            if Des=="A": 
                print("DatArm1")
            elif Des=="B":
                print("DatArm2")
            elif Des=="C":
                print("DatArm3")
            elif Des=="D":
                print("DatArm4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Armenia
            Des=input("Selecciona un cantante\n A. CanArm1 \n B. CanArm1 \n C. CanArm1 \n D. CanArm1 \n ").upper()
            if Des=="A": 
                print("Biografía de CanArm1")
            elif Des=="B":
                print("Biografía de CanArm1")
            elif Des=="C":
                print("Biografía de CanArm1")
            elif Des=="D":
                print("Biografía de CanArm1")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Armenia
    elif Ciu =="B": # Selecciona Pereira
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Pereira
            Des=input("Selecciona un restaurante\n A. ComPer1 \n B. ComPer2 \n C. ComPer3 \n D. ComPer4 \n ").upper()
            if Des=="A":
                print("Descripción de ComPer1")
            elif Des=="B":
                print("Descripción de ComPer2")
            elif Des=="C":
                print("Descripción de ComPer3")
            elif Des=="D":
                print("Descripción de ComPer4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Pereira
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Pereira")
            elif Des=="B":
                print("Descripción de Mamiferos de Pereira")
            elif Des=="C":
                print("Descripción de Anfibios de Pereira")
            elif Des=="D":
                print("Descripción de Reptiles de Pereira")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Pereira
            Des=input("Selecciona un dato histórico\n A. DatPer1 \n B. DatPer2 \n C. DatPer3 \n D. DatPer4 \n ").upper()
            if Des=="A": 
                print("DatPer1")
            elif Des=="B":
                print("DatPer2")
            elif Des=="C":
                print("DatPer3")
            elif Des=="D":
                print("DatPer4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Pereira
            Des=input("Selecciona un cantante\n A. CanPer1 \n B. CanPer2 \n C. CanPer3 \n D. CanPer4 \n ").upper()
            if Des=="A": 
                print("Biografía de CanPer1")
            elif Des=="B":
                print("Biografía de CanPer2")
            elif Des=="C":
                print("Biografía de CanPer3")
            elif Des=="D":
                print("Biografía de CanPer4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI CanPereira    
    elif Ciu =="C":# Selecciona Manizales
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Manizales
            Des=input("Selecciona un restaurante\n A. ComMan1 \n B. ComMan2 \n C. ComMan3 \n D. ComMan4 \n ").upper()
            if Des=="A":
                print("Descripción de ComMan1")
            elif Des=="B":
                print("Descripción de ComMan2")
            elif Des=="C":
                print("Descripción de ComMan3")
            elif Des=="D":
                print("Descripción de ComMan4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Manizales
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Manizales")
            elif Des=="B":
                print("Descripción de Mamiferos de Manizales")
            elif Des=="C":
                print("Descripción de Anfibios de Manizales")
            elif Des=="D":
                print("Descripción de Reptiles de Manizales")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Manizales
            Des=input("Selecciona un dato histórico\n A. DatMan1 \n B. DatMan2 \n C. DatMan3 \n D. DatMan4 \n ").upper()
            if Des=="A": 
                print("DatMan1")
            elif Des=="B":
                print("DatMan2")
            elif Des=="C":
                print("DatMan3")
            elif Des=="D":
                print("DatMan4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Manizales
            Des=input("Selecciona un cantante\n A. CanMan1 \n B. CanMan2 \n C. CanMan3 \n D. CanMan4 \n ").upper()
            if Des=="A": 
                print("Biografía de CanMan1")
            elif Des=="B":
                print("Biografía de CanMan2")
            elif Des=="C":
                print("Biografía de CanMan3")
            elif Des=="D":
                print("Biografía de CanMan4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Manizales
    elif Ciu =="D": # Selecciona Cartago
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Cartago
            Des=input("Selecciona un restaurante\n A. ComCart1 \n B. ComCart2 \n C. ComCart3 \n D. ComCart4 \n ").upper()
            if Des=="A":
                print("Descripción de ComCart1")
            elif Des=="B":
                print("Descripción de ComCart2")
            elif Des=="C":
                print("Descripción de ComCart3")
            elif Des=="D":
                print("Descripción de ComCart4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Cartago
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Cartago")
            elif Des=="B":
                print("Descripción de Mamiferos de Cartago")
            elif Des=="C":
                print("Descripción de Anfibios de Cartago")
            elif Des=="D":
                print("Descripción de Reptiles de Cartago")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Cartago
            Des=input("Selecciona un dato histórico\n A. DatCart1 \n B. DatCart2 \n C. DatCart3 \n D. DatCart4 \n ").upper()
            if Des=="A": 
                print("DatCart1")
            elif Des=="B":
                print("DatCart2")
            elif Des=="C":
                print("DatCart3")
            elif Des=="D":
                print("DatCart4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Cartago
            Des=input("Selecciona un cantante\n A. CanCart1 \n B. CanCart2 \n C. CanCart3 \n D. CanCart4 \n ").upper()
            if Des=="A": 
                print("Biografía de CanCart1")
            elif Des=="B":
                print("Biografía de CanCart2")
            elif Des=="C":
                print("Biografía de CanCart3")
            elif Des=="D":
                print("Biografía de CanCart4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Cartago          
    else:
        print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de Ciudad
elif Sel =="D":# Valle
    Ciu=input("Selecciona una Ciudad\n A. Cali \n B. Palmira \n C. Tulua \n D. Buenaventura \n ").upper()
    if Ciu == "A": #Selecciona Cali
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Cali
            Des=input("Selecciona un restaurante\n A. ComCali1 \n B. ComCali2 \n C. ComCali3 \n D. ComCali4 \n ").upper()
            if Des=="A":
                print("Descripción de ComCali1")
            elif Des=="B":
                print("Descripción de ComCali2")
            elif Des=="C":
                print("Descripción de ComCali3")
            elif Des=="D":
                print("Descripción de ComCali4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Cali
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Cali")
            elif Des=="B":
                print("Descripción de Mamiferos de Cali")
            elif Des=="C":
                print("Descripción de Anfibios de Cali")
            elif Des=="D":
                print("Descripción de Reptiles de Cali")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Cali
            Des=input("Selecciona un dato histórico\n A. DatCali1 \n B. DatCali2 \n C. DatCali3 \n D. DatCali4 \n ").upper()
            if Des=="A": 
                print("DatCali1")
            elif Des=="B":
                print("DatCali2")
            elif Des=="C":
                print("DatCali3")
            elif Des=="D":
                print("DatCali4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Cali
            Des=input("Selecciona un cantante\n A. CanCali1 \n B. CanCali1 \n C. CanCali1 \n D. CanCali1 \n ").upper()
            if Des=="A": 
                print("Biografía de CanCali1")
            elif Des=="B":
                print("Biografía de CanCali2")
            elif Des=="C":
                print("Biografía de CanCali3")
            elif Des=="D":
                print("Biografía de CanCali4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Armenia
    elif Ciu =="B": # Selecciona Palmira
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Palmira
            Des=input("Selecciona un restaurante\n A. ComPal1 \n B. ComPal2 \n C. ComPal3 \n D. ComPal4 \n ").upper()
            if Des=="A":
                print("Descripción de ComPal1")
            elif Des=="B":
                print("Descripción de ComPal2")
            elif Des=="C":
                print("Descripción de ComPal3")
            elif Des=="D":
                print("Descripción de ComPal4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Palmira
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Palmira")
            elif Des=="B":
                print("Descripción de Mamiferos de Palmira")
            elif Des=="C":
                print("Descripción de Anfibios de Palmira")
            elif Des=="D":
                print("Descripción de Reptiles de Palmira")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Palmira
            Des=input("Selecciona un dato histórico\n A. DatPal1 \n B. DatPal2 \n C. DatPal3 \n D. DatPal4 \n ").upper()
            if Des=="A": 
                print("DatPal1")
            elif Des=="B":
                print("DatPal2")
            elif Des=="C":
                print("DatPal3")
            elif Des=="D":
                print("DatPal4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Palmira
            Des=input("Selecciona un cantante\n A. CanPal1 \n B. CanPal2 \n C. CanPal3 \n D. CanPal4 \n ").upper()
            if Des=="A": 
                print("Biografía de CanPal1")
            elif Des=="B":
                print("Biografía de CanPal2")
            elif Des=="C":
                print("Biografía de CanPal3")
            elif Des=="D":
                print("Biografía de CanPal4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Palmira    
    elif Ciu =="C":# Selecciona Tulua
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Tulua
            Des=input("Selecciona un restaurante\n A. ComTul1 \n B. ComTul2 \n C. ComTul3 \n D. ComTul4 \n ").upper()
            if Des=="A":
                print("Descripción de ComTul1")
            elif Des=="B":
                print("Descripción de ComTul2")
            elif Des=="C":
                print("Descripción de ComTul3")
            elif Des=="D":
                print("Descripción de ComTul4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Tulua
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Tulua")
            elif Des=="B":
                print("Descripción de Mamiferos de Tulua")
            elif Des=="C":
                print("Descripción de Anfibios de Tulua")
            elif Des=="D":
                print("Descripción de Reptiles de Tulua")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Tulua
            Des=input("Selecciona un dato histórico\n A. DatTul1 \n B. DatTul2 \n C. DatTul3 \n D. DatTul4 \n ").upper()
            if Des=="A": 
                print("DatTul1")
            elif Des=="B":
                print("DatTul2")
            elif Des=="C":
                print("DatTul3")
            elif Des=="D":
                print("DatTul4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Tulua
            Des=input("Selecciona un cantante\n A. CanTul1 \n B. CanTul2 \n C. CanTul3 \n D. CanTul4 \n ").upper()
            if Des=="A": 
                print("Biografía de CanTul1")
            elif Des=="B":
                print("Biografía de CanTul2")
            elif Des=="C":
                print("Biografía de CanTul3")
            elif Des=="D":
                print("Biografía de CanTul4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Tulua
    elif Ciu =="D": # Selecciona Buenaventura
        OpI=input("Selecciona algo de tu interés\n A. Comidas \n B. Fauna \n C. Datos históricos \n D. Música \n ").upper()
        if OpI == "A": #Selecciona Comidas de Buenaventura
            Des=input("Selecciona un restaurante\n A. ComBuen1 \n B. ComBuen2 \n C. ComBuen3 \n D. ComBuen4 \n ").upper()
            if Des=="A":
                print("Descripción de ComBuen1")
            elif Des=="B":
                print("Descripción de ComBuen2")
            elif Des=="C":
                print("Descripción de ComBuen3")
            elif Des=="D":
                print("Descripción de ComBuen4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Comidas
        elif OpI =="B": #Fauna de Buenaventura
            Des=input("Selecciona un opción\n A. Aves \n B. Mamiferos \n C. Anfibios \n D. Reptiles \n ").upper()
            if Des=="A": 
                print("Descripción de Aves de Buenaventura")
            elif Des=="B":
                print("Descripción de Mamiferos de Buenaventura")
            elif Des=="C":
                print("Descripción de Anfibios de Buenaventura")
            elif Des=="D":
                print("Descripción de Reptiles de Buenaventura")
            else:
                print("Esa opción no existe\n vuelve a reiniciar")# Error de seleccion de Descripcion Fauna
        elif OpI =="C": # Datos históricos de Buenaventura
            Des=input("Selecciona un dato histórico\n A. DatBuen1 \n B. DatBuen2 \n C. DatBuen3 \n D. DatBuen4 \n ").upper()
            if Des=="A": 
                print("DatBuen1")
            elif Des=="B":
                print("DatBuen2")
            elif Des=="C":
                print("DatBuen3")
            elif Des=="D":
                print("DatBuen4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion historico
        elif OpI =="D": # Musica de Buenaventura
            Des=input("Selecciona un cantante\n A. CanBuen1 \n B. CanBuen2 \n C. CanBuen3 \n D. CanBuen4 \n ").upper()
            if Des=="A": 
                print("Biografía de CanBuen1")
            elif Des=="B":
                print("Biografía de CanBuen2")
            elif Des=="C":
                print("Biografía de CanBuen3")
            elif Des=="D":
                print("Biografía de CanBuen4")
            else:
                print("Esa opción no existe\n vuelve a reiniciar") # Error de seleccion de Descripcion musica
        else:
            print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de OpI Buenaventura          
    else:
        print("Esa opción no existe\n vuelve a reiniciar") #Error de seleccion de Ciudad
else:
    print("Esa opción no existe\nVuelve a reiniciarlo") # Error de seleccion de departamento
# Out:
# Elige un Departamento
#  A. Antioquia
#  B. Cundinamarca
#  C. Quindio
#  D. Valle
#  a
# Selecciona una Ciudad
#  A. Medellin
#  B. Rionegro
#  C. Caldas
#  D. Guatape
#  g
# Esa opción no existe
#  vuelve a reiniciar
