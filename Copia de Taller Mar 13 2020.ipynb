# %%
import PlayMain as PM


print("-------------------------------------\n\n")
Char=["Warrior","Mage","Elf"]
Mons=["Centaur","Skeleton","Slime"]
for i in Char:
    print(Char.index(i),i)
while True:
    try:
        s=int(input('\nPlease, Select a number Character\n'))
        break
    except ValueError:
        print("\nTry again, Please Select from the list\n")
        for i in Char:
            print(Char.index(i),i)
    except Exception as ex: # Si no puede, entonces haga, un "Exception" es cualquier error que salga
        print(f"An another error ocurred {type(ex)}{ex}")
print(f'\nYou choose to play as a {Char[s]}')
n=input("\nType your name\n").upper()
print(f'{Char[s]} {n} has born')
if s ==0:
    s=PM.Warrior(f'Warrior {n}', 100,20,"Axes","Hammer",10,60,0)
elif s==1:
    s=PM.Mage(f'Mage {n}', 100,20,"Fire","Water",10,60,0)
elif s==2:
    s=PM.Elf(f'Elf {n}', 100,20,"Arrows","Nature",10,60,0)

print("-------------------------------------\n\n")
for j in Mons:
    print(Mons.index(j),j)

while True:
    try:
        o=int(input('\nPlease, Select a number Opponent\n'))
        break
    except ValueError:
        print("\nTry again, Please Select from the list\n")
        for j in Mons:
            print(Mons.index(j),j)
    except Exception as ex: # Si no puede, entonces haga, un "Exception" es cualquier error que salga
        print(f"An another error ocurred {type(ex)}{ex}")
print(f'\nYou choose to fight {Mons[o]}')
print(f'\n{Mons[o]} has accept the challenge ')

if o==0:
    o=PM.Centaur(f'Centaur', 100,20,"Front kicks","Back kicks",10,60,0)
elif o==1:
    o=PM.Skeleton(f'Skeleton', 100,20,"Bone throw","Bone hit",10,60,0)
elif o==2:
    o=PM.Slime(f'Slime', 100,20,"Copy","Sofocate",10,60,0)
    

print("-------------------------------------\n\n")
s.intro()
s.mission()

print("-------------------------------------\n\n")
o.intro()
o.mission()

print("-----------------DUEL--------------------\n\n")
while True:
    if o.hp <= 0:
        False
        break
    elif s.hp<=0:
        False
        break
    s.attack(o)
    print("-------------------------------------\n\n")
    o.attack(s)
    print("-------------------------------------\n\n")
# Out:
# -------------------------------------
#
#
# 0 Warrior
# 1 Mage
# 2 Elf
#
# Please, Select a number Character
# 0
#
# You choose to play as a Warrior
#
# Type your name
# tao
# Warrior TAO has born
# -------------------------------------
#
#
# 0 Centaur
# 1 Skeleton
# 2 Slime
#
# Please, Select a number Opponent
# 0
#
# You choose to fight Centaur
#
# Centaur has accept the challenge
# -------------------------------------
#
#
# I'm Warrior TAO i have
# HP: 100
# Attack: 20
# Powers: Axes, Hammer
# Defense: 10
# Mana: 60
# My mission is to Get the treasure
# -------------------------------------
#
#
# I'm Centaur i have
# HP: 100
# Attack: 20
# Powers: Front kicks, Back kicks
# Defense: 10
# Mana: 60
# My mission is to Defend the treasure
# -----------------DUEL--------------------
#
#
# Warrior TAO choose an attack power
# A:Axes
# B:Hammer
# a
# Warrior TAO attacked with Axes to Centaur
# Warrior TAO miss attack to Centaur
# -------------------------------------
#
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8980eb2716f6> in <module>
# ----> 1 local.Hist
#
# NameError: name 'local' is not defined
